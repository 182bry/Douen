# %% [markdown]
# # Multi-Source Dataset Summary
#
# This notebook summarizes the three cybersecurity datasets currently used in the DOUEN project:
#
# - CICIDS2017
# - UNSW-NB15
# - CTU-13
#
# The goal of this notebook is to document data scale, schema differences, and dataset characteristics before model development.

# %%
import pandas as pd

cicids = pd.read_parquet("../data/processed/cicids2017.parquet")
unsw = pd.read_parquet("../data/processed/unsw_nb15.parquet")
ctu13 = pd.read_parquet("../data/processed/ctu13.parquet")

# %% [markdown]
# ## Dataset Shapes

# %%
print("CICIDS2017 shape:", cicids.shape)
print("UNSW-NB15 shape:", unsw.shape)
print("CTU-13 shape:", ctu13.shape)
